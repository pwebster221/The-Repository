# %% [markdown]
# # data structures for astro-api

# %% [markdown]
# ## Planetary Positions
# ### Swiss Ephemeris Query Return
# name of planet
# longitute
# lattitude
# distance from earth
# motion, speed
# retrograde motion
# ### Equivalent Sign/Degree
# Sign
# Degree
#
# ### House Position
# House
# For Natal Charts, this is also where House position is added, same for chart comparison, always presented as in the house of the Natal, self, and acted upon

# %% [markdown]
# ## Planetary Aspects
# ### Within a Single Chart (ie Natal, Pure Transit)
# planet 1 (slower moving planet)
# planet 2 (fastr moving planet)
# aspect formed
# orb at date pulled
# if applicable, when is the Aspect Exact
# basic writeup of potential aspect effects
# ### When comparing two charts (ie Transit to Natal, Synnastry Chart)
# planet 1 (active/transiting/other in synnastry)
# planet 2 (acted upon/natal/self in synnastry)
# aspect formed
# orb for date pulled
# transit begins date
# transit exact date
# transit ends date

# %% [markdown]
# ##     1st House - Sign/Degree(if applicable)Natal Chart
# Birth Date
# Birth Time
# Birth Location
# Natal House Cusps
#     1st House - Sign/Degree(if applicable)
#     2nd House - Sign/Degree(if applicable)
#     3rd House - Sign/Degree(if applicable)
#     4th House - Sign/Degree(if applicable)
#     5th House - Sign/Degree(if applicable)
#     6th House - Sign/Degree(if applicable)
#     7th House - Sign/Degree(if applicable)
#     8th House - Sign/Degree(if applicable)
#     9th House - Sign/Degree(if applicable)
#     10th House - Sign/Degree(if applicable)
#     11th House - Sign/Degree(if applicable)
#     12th House - Sign/Degree(if applicable)
# Planetary Positions for:
#     Sun
#     Moon
#     Mercury
#     Venus
#     Mars
#     Jupiter
#     Saturn
#     Uranus
#     Neptune
#     Pluto
#     N Node/ S Node
#     Asc/Desc
#     Mid/Nadir
#     Chiron
#     Lilith
#     Pallas Athena
#     Ceres
#     Juno
#     Vestia
#     Vertex
# Natal Aspects
#     Vertex to __
#     Vestia to __
#     Juno to __
#     Ceres to __
#     Pallas Athena to __
#     Lilith to __
#     Chiron to __
#     Midheaven to __
#     Ascendant to __
#     Pluto to __
#     Neptune to __
#     Uranus to __
#     Saturn to __
#     Jupiter to __
#     Mars to __
#     Venus to __
#     Mercury to __
#     Moon to __
#     Sun to __

# %% [markdown]
# ## Pure Transit Chart
# Transiting Date
# Transiitng Time
# Transiting Location
# Transiting House Cusps
#     1st House - Sign/Degree(if applicable)
#     2nd House - Sign/Degree(if applicable)
#     3rd House - Sign/Degree(if applicable)
#     4th House - Sign/Degree(if applicable)
#     5th House - Sign/Degree(if applicable)
#     6th House - Sign/Degree(if applicable)
#     7th House - Sign/Degree(if applicable)
#     8th House - Sign/Degree(if applicable)
#     9th House - Sign/Degree(if applicable)
#     10th House - Sign/Degree(if applicable)
#     11th House - Sign/Degree(if applicable)
#     12th House - Sign/Degree(if applicable)
# Planetary Positions for:
#     Sun
#     Moon
#     Mercury
#     Venus
#     Mars
#     Jupiter
#     Saturn
#     Uranus
#     Neptune
#     Pluto
#     N Node/ S Node
#     Asc/Desc
#     Mid/Nadir
#     Chiron
#     Lilith
#     Pallas Athena
#     Ceres
#     Juno
#     Vestia
#     Vertex
# Transitig Aspects
#     Vertex to __
#     Vestia to __
#     Juno to __
#     Ceres to __
#     Pallas Athena to __
#     Lilith to __
#     Chiron to __
#     Midheaven to __
#     Ascendant to __
#     Pluto to __
#     Neptune to __
#     Uranus to __
#     Saturn to __
#     Jupiter to __
#     Mars to __
#     Venus to __
#     Mercury to __
#     Moon to __
#     Sun to __

# %% [markdown]
# ## Transit Chart to Natal Chart
# Transit Chart
# Natal Chart
# Transiting Planet in Natal Houses
#     Sun in __
#     Moon in __
#     Mercury in __
#     etc.
# Transiting Planet Aspects to Natal Planets
#     Transiting Pluto to Natal ___
#     Transiting Neptune to Natal ___
#     etc.
